# %% [markdown]
# ## Main function test

# %%
#-*- coding=utf-8 -*-
import requests
import json
import time
import hashlib
import pandas as pd
from datetime import datetime

URL = "https://s5.securepilot.com/parking/v1/query_record"
api_key = "PARK-eMPpua7y17"
api_secret = "2PHIAGI5qv5IhMGZ56iy"

mac_gemtek = "101a"
mac_address1 = mac_gemtek + "0d0100ab"
mac_address_test = mac_gemtek + "0d01019a"

def byteToMagData(Low_byte, High_byte):
    return twos_comp(byte2SwapToNumber(Low_byte,High_byte), 16)

def byte2SwapToNumber(Low_byte, High_byte):
    return int(Low_byte.encode(), 16) + int(High_byte.encode(), 16) * 256

def twos_comp(val, bits):
    """compute the 2's complement of int value val"""
    if (val & (1 << (bits - 1))) != 0: # if sign bit is set e.g., 8bit: 128-255
        val = val - (1 << bits)        # compute negative value
    return val 

def getParkDataResponse(URL, api_key, api_secret, macID):
    current_unix_time = str(int(time.time()))
    api_token = hashlib.sha1((api_secret + current_unix_time).encode('utf-8')).hexdigest()
    index = 0
    limit = 2
    print("------------- RESTful API parameter --------------")
    print("mac: ", macID)
    print("api_key: ", api_key)
    print("api_secret: ", api_secret)
    print("unix_time: ", current_unix_time)
    print("api_token: ", api_token)
    print("index: ", index, "limit: ", limit)
    print("--------------------------------------------------\n")

    if len(macID) != 12:
        print("mac address is ilegal !!")

#     payload = { "index" : 1, "limit" : 20, "mac" : macID, 
#            "api_key" : api_key, "api_token" : api_token, "time" : current_unix_time
#            }
#     payload = {
#         'mac' : macID, 
#         'api_key' : api_key, 
#         'api_token' : api_token, 
#         'time' : current_unix_time 
#     }
    
    payload = {
        "index": index,
        "limit" : limit,
        "mac" : "101a0d01019a",
        "api_key" : "PARK-eMPpua7y17",
        "api_token" : "7a5db58d81e51ce9cb5a7731d6c6b7fa1bb0144a",
        "time" : "1500874971"
    }
    print("------------- Payload Check ----------------------")
    print("Payload:", payload)
    print("--------------------------------------------------\n")

#     return requests.post(URL, data = payload)
    return requests.post(URL, json = payload)

def getPraseTargetData(req):
    prase_data = prase_data['value']['hits']
    
    prase_data_from_json = []
    # columes in data frame
    prase_data_columes = ['_id', '_index', 'create_at_time','recv_at_time','data',
                          'company','road','slot_num','gwip', 
                          "magX", "magY", "magZ", "magT"]
    # get data by list
    for each in prase_data:
        fullData = []
        pakcetHeader = "fcffff07"
        packetByte = []
        
        fullData = [ each['_id'], each['_index'], 
             each['_source']['create_at'], each['_source']['recv'],
             each['_source']['data'],
             each['_source']['extra']['company'],  each['_source']['extra']['road'], 
             each['_source']['extra']['slot_num'], each['_source']['gwip']
        ]
        
        # get high/ low byte
        packetMagData = each['_source']['data']
        
        if packetMagData.find(pakcetHeader) != -1:
            index = [i for i in range(len(packetMagData)) if i % 2 == 0]   
            for each in index:
                packetByte.append(packetMagData[each:each+2])
#             print("packet Byte: ", packetByte)
        else:
            print("packet header error")

        magX = byteToMagData(packetByte[4], packetByte[5])
        magY = byteToMagData(packetByte[6], packetByte[7])
        magZ = byteToMagData(packetByte[8], packetByte[9])
        magT = byteToMagData(packetByte[10], '00')
        
        fullData.extend([magX, magY, magZ, magT])
        print("Data:", fullData)
        prase_data_from_json.append(fullData)
       
    return pd.DataFrame(prase_data_from_json, columns=prase_data_columes) 


# main funciton
req = getParkDataResponse(URL, api_key, api_secret, mac_address_test)
server_ReturnCode = req.json()['status']['code']
server_ReturnMsg = req.json()['status']['message']

if(req.ok and server_ReturnCode == 1200):
    print("------------- Request Status ---------------------")
    print("Request URL: ",req.url, ", Status: OK ")
    print("--------------------------------------------------\n")
    
    df = getPraseTargetData(req)
    NodeName = df['slot_num'][0]
    timeName = datetime.now().strftime('%Y%m%d_%H%M%S')
    csvFileName = timeName + '_' + NodeName + '.csv'
    df.to_csv(csvFileName, encoding='utf_8_sig')
else:
     print("Status: FAIL , Server return code ",server_ReturnCode, ", Msg :", server_ReturnMsg)
    
# #     print(req.text)
# Out:
# ------------- RESTful API parameter --------------
# mac:  101a0d01019a
# api_key:  PARK-eMPpua7y17
# api_secret:  2PHIAGI5qv5IhMGZ56iy
# unix_time:  1501139831
# api_token:  118dba38cfed8b07d99c576cb04b9ebefb70537c
# index:  0 limit:  2
# --------------------------------------------------
#
# ------------- Payload Check ----------------------
# Payload: {'index': 0, 'limit': 2, 'mac': '101a0d01019a', 'api_key': 'PARK-eMPpua7y17', 'api_token': '7a5db58d81e51ce9cb5a7731d6c6b7fa1bb0144a', 'time': '1500874971'}
# --------------------------------------------------
#
# ------------- Request Status ---------------------
# Request URL:  https://s5.securepilot.com/parking/v1/query_record , Status: OK
# --------------------------------------------------
#
# Data: ['AV197R2L-R03vmj0K7en', 'parking_record_index_v2', '2017-07-26T08:04:37.898Z', '2017-07-26T08:04:37.000Z', 'fcffff072d001100f4001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 45, 17, 244, 28]
# Data: ['AV197Q3r-R03vmj0K7ei', 'parking_record_index_v2', '2017-07-26T08:04:33.897Z', '2017-07-26T08:04:33.000Z', 'fcffff072f000b00f8001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 47, 11, 248, 28]

# %% [markdown]
# ## API Class

# %%
from datetime import datetime
import hashlib

class Gemtek_restful_api:
    def __init__(self, URL, api_key, api_secret, macID, index = 0, limit = 10, start_time = 0):
        self.URL = URL
        self.api_key = api_key
        self.api_secret = api_secret
        self.macID = macID
        self.index = index
        self.limit = limit
        self.start_time = start_time
        self.time = str(int(time.time()))
        self.api_token = hashlib.sha1((self.api_secret + self.time).encode('utf-8')).hexdigest()
        self.payload = {
            "index": self.index,
            "limit" : self.limit,
            "mac" : self.macID,
            "api_key" : self.api_key,
            "api_token" : self.api_token,
            "time" : self.time
        }
        self.jsonData = None
        self.request_OK = None
        self.jsonDataLength = None
        
        if len(macID) != 12:
            print("mac address is ilegal !!")
        
    def set_query_index(self, index ):
        self.index = index

    def set_query_limit(self, limit ):
        self.limit = limit
        
    def set_query_start_time(self, start_time ):
        self.start_time = start_time     
        
        
    def print_API_parameter(self):
        print("------------- RESTful API parameter --------------")
        print("mac: ", self.macID)
        print("api_key: ", self.api_key)
        print("api_secret: ", self.api_secret)
        print("unix_time: ", self.time)
        print("api_token: ", self.api_token)
        print("index: ", self.index, "limit: ", self.limit)
        print("Payload:", self.payload)
        print("--------------------------------------------------\n")
        
    def get_query_data(self):    
        req = requests.post(self.URL, json = self.payload)
        self.jsonData = req.json()
        self.jsonDataLength = self.jsonData['value']['total']
        server_ReturnCode = self.jsonData['status']['code']
        server_ReturnMsg = self.jsonData['status']['message']
        
        if (server_ReturnCode == 1200):
            self.request_OK = True
        else:
            self.request_OK = False
        
        print("------------- Request Status ---------------------")
        print("Request URL: ", req.url)
        print("Server return code: ",server_ReturnCode, ", Msg :", server_ReturnMsg)
        print("Packet Length: ", self.jsonDataLength)
        print("--------------------------------------------------\n")
     
        return self.jsonData
    
    def update_new_api_token(self):    
        self.time = str(int(time.time()))
        self.api_token = hashlib.sha1((self.api_secret + self.time).encode('utf-8')).hexdigest()
        self.payload["time"] = self.time
        self.payload["api_token"] = self.api_token

# %%
lenth = 1000
test_api = Gemtek_restful_api(URL, api_key, api_secret, mac_address1, limit = lenth)
test_api.print_API_parameter()
query_JsonData = test_api.get_query_data()
# Out:
# ------------- RESTful API parameter --------------
# mac:  101a0d0100ab
# api_key:  PARK-eMPpua7y17
# api_secret:  2PHIAGI5qv5IhMGZ56iy
# unix_time:  1501152317
# api_token:  633e82f4f15a6d36a5ecc9fb61595f0253bd0918
# index:  0 limit:  1000
# Payload: {'index': 0, 'limit': 1000, 'mac': '101a0d0100ab', 'api_key': 'PARK-eMPpua7y17', 'api_token': '633e82f4f15a6d36a5ecc9fb61595f0253bd0918', 'time': '1501152317'}
# --------------------------------------------------
#
# ------------- Request Status ---------------------
# Request URL:  https://s5.securepilot.com/parking/v1/query_record
# Server return code:  1200 , Msg : Command succeeded
# Packet Length:  1899
# --------------------------------------------------

# %%
def byteToMagData(Low_byte, High_byte):
    value = int(Low_byte.encode(), 16) + int(High_byte.encode(), 16) * 256
    return twos_comp(value, 16)

def twos_comp(val, bits):
    """compute the 2's complement of int value val"""
    if (val & (1 << (bits - 1))) != 0: # if sign bit is set e.g., 8bit: 128-255
        val = val - (1 << bits)        # compute negative value
    return val 

def getPraseTargetData(Data):
    pakcetHeader = "fcffff07"
    prase_data = Data['value']['hits']
    prase_data_from_json = []
    
    # columes in data frame
    prase_data_columes = ['_id', '_index', 'create_at_time','recv_at_time','data',
                          'company','road','slot_num','gwip', 
                          "magX", "magY", "magZ", "magT"]
    # get data by list
    for each in prase_data:
        fullData = []
        packetByte = []
        
        fullData = [ each['_id'], each['_index'], 
             each['_source']['create_at'], each['_source']['recv'],
             each['_source']['data'],
             each['_source']['extra']['company'],  each['_source']['extra']['road'], 
             each['_source']['extra']['slot_num'], each['_source']['gwip']
        ]
        
        # get high/ low byte
        packetMagData = each['_source']['data']
        
        if packetMagData.find(pakcetHeader) != -1:
            index = [i for i in range(len(packetMagData)) if i % 2 == 0]   
            for each in index:
                packetByte.append(packetMagData[each:each+2])
#             print("packet Byte: ", packetByte)
        else:
            print("packet header error")

        magX = byteToMagData(packetByte[4], packetByte[5])
        magY = byteToMagData(packetByte[6], packetByte[7])
        magZ = byteToMagData(packetByte[8], packetByte[9])
        magT = byteToMagData(packetByte[10], '00')
        
        fullData.extend([magX, magY, magZ, magT])
        print("Data:", fullData)
        prase_data_from_json.append(fullData)
       
    return pd.DataFrame(prase_data_from_json, columns=prase_data_columes)

# %%
#-*- coding=utf-8 -*-
import requests
import json
import time
import hashlib
import pandas as pd
from datetime import datetime

URL = "https://s5.securepilot.com/parking/v1/query_record"
api_key = "PARK-eMPpua7y17"
api_secret = "2PHIAGI5qv5IhMGZ56iy"

mac_gemtek = "101a"
mac_address1 = mac_gemtek + "0d0100ab"
mac_address_test = mac_gemtek + "0d01019a"

# main funciton
test_api = Gemtek_restful_api(URL, api_key, api_secret, mac_address_test)
test_api.print_API_parameter()
query_JsonData = test_api.get_query_data()

if(test_api.request_OK):
    df = getPraseTargetData(query_JsonData)
#     NodeName = df['slot_num'][0]
#     timeName = datetime.now().strftime('%Y%m%d_%H%M%S')
#     csvFileName = timeName + '_' + NodeName + '.csv'
    csvFileName = "Node_" + mac_address_test + '_' + "test" + '.csv'
    
    df.to_csv(csvFileName, encoding='utf_8_sig')
else:
    print("Server Request Fail")
# Out:
# ------------- RESTful API parameter --------------
# mac:  101a0d01019a
# api_key:  PARK-eMPpua7y17
# api_secret:  2PHIAGI5qv5IhMGZ56iy
# unix_time:  1501152635
# api_token:  a5e38fd73e37ac710e005c8e5785c7572ab2cbd0
# index:  0 limit:  10
# Payload: {'index': 0, 'limit': 10, 'mac': '101a0d01019a', 'api_key': 'PARK-eMPpua7y17', 'api_token': 'a5e38fd73e37ac710e005c8e5785c7572ab2cbd0', 'time': '1501152635'}
# --------------------------------------------------
#
# ------------- Request Status ---------------------
# Request URL:  https://s5.securepilot.com/parking/v1/query_record
# Server return code:  1200 , Msg : Command succeeded
# Packet Length:  479
# --------------------------------------------------
#
# Data: ['AV197R2L-R03vmj0K7en', 'parking_record_index_v2', '2017-07-26T08:04:37.898Z', '2017-07-26T08:04:37.000Z', 'fcffff072d001100f4001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 45, 17, 244, 28]
# Data: ['AV197Q3r-R03vmj0K7ei', 'parking_record_index_v2', '2017-07-26T08:04:33.897Z', '2017-07-26T08:04:33.000Z', 'fcffff072f000b00f8001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 47, 11, 248, 28]
# Data: ['AV197P5A-R03vmj0K7ef', 'parking_record_index_v2', '2017-07-26T08:04:29.887Z', '2017-07-26T08:04:29.000Z', 'fcffff072f000b00f8001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 47, 11, 248, 28]
# Data: ['AV197O6a-R03vmj0K7eU', 'parking_record_index_v2', '2017-07-26T08:04:25.881Z', '2017-07-26T08:04:25.000Z', 'fcffff072f000b00f8001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 47, 11, 248, 28]
# Data: ['AV197N8V-R03vmj0K7eR', 'parking_record_index_v2', '2017-07-26T08:04:21.908Z', '2017-07-26T08:04:21.000Z', 'fcffff072f000b00f8001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 47, 11, 248, 28]
# Data: ['AV197M9m-R03vmj0K7eP', 'parking_record_index_v2', '2017-07-26T08:04:17.893Z', '2017-07-26T08:04:17.000Z', 'fcffff072f000b00f8001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 47, 11, 248, 28]
# Data: ['AV197MCv-R03vmj0K7eG', 'parking_record_index_v2', '2017-07-26T08:04:14.126Z', '2017-07-26T08:04:13.000Z', 'fcffff072f000c00f8001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 47, 12, 248, 28]
# Data: ['AV197MBt-R03vmj0K7eF', 'parking_record_index_v2', '2017-07-26T08:04:14.060Z', '2017-07-26T08:04:13.000Z', 'fcffff072f000c00f8001c', 'yilan', '宜蘭市中山路二段', '111', '192.168.88.122', 47, 12, 248, 28]
# Data: ['AV197L_--R03vmj0K7eE', 'parking_record_index_v2', '2017-07-26T08:04:13.949Z', '2017-07-26T08:04:13.000Z', 'fcffff072f000c00f8001c', 'yilan', '宜蘭市中山路二段', '111', '192.168.0.3', 47, 12, 248, 28]
# Data: ['AV197L_9-R03vmj0K7eD', 'parking_record_index_v2', '2017-07-26T08:04:13.947Z', '2017-07-26T08:03:05.000Z', 'fcffff072f000c00f8001c', 'yilan', '宜蘭市中山路二段', '111', '192.168.0.225', 47, 12, 248, 28]

# %%
query_JsonData
# Out:
# {'status': {'code': 1200, 'message': 'Command succeeded'},
#  'value': {'hits': [{'_id': 'AV2DJ2yc-R03vmj0LJ1i',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:26:25.307Z',
#      'data': 'fc000105600bb60122',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 1,
#       'status': False,
#       'temperature': 34,
#       'voltage': 2.998},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 339,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:25:14.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -89,
#      'sf': 10,
#      'snr': 19.5,
#      'snr_max': 24.5,
#      'snr_min': 14.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DJ2WS-R03vmj0LJ1e',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:26:23.504Z',
#      'data': 'fc000105600bb60122',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 1,
#       'status': False,
#       'temperature': 34,
#       'voltage': 2.998},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 339,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:26:23.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -95,
#      'sf': 10,
#      'snr': 25.8,
#      'snr_max': 31.3,
#      'snr_min': 23.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DJ2VX-R03vmj0LJ1d',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:26:23.446Z',
#      'data': 'fc000105600bb60122',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 1,
#       'status': False,
#       'temperature': 34,
#       'voltage': 2.998},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 339,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:26:23.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -102,
#      'sf': 10,
#      'snr': 22.5,
#      'snr_max': 28.8,
#      'snr_min': 20,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DJ2Uq-R03vmj0LJ1c',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:26:23.400Z',
#      'data': 'fc000105600bb60122',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 1,
#       'status': False,
#       'temperature': 34,
#       'voltage': 2.998},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 339,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:26:23.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -108,
#      'sf': 10,
#      'snr': 17,
#      'snr_max': 20.5,
#      'snr_min': 13,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DJ1lc-R03vmj0LJ1a',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:26:20.378Z',
#      'data': 'fc000105600bb60122',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 1,
#       'status': False,
#       'temperature': 34,
#       'voltage': 2.998},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 339,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:25:11.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -93,
#      'sf': 10,
#      'snr': 15.5,
#      'snr_max': 21.2,
#      'snr_min': 11.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DJ1lA-R03vmj0LJ1Z',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:26:20.350Z',
#      'data': 'fc000105600bb60122',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 1,
#       'status': False,
#       'temperature': 34,
#       'voltage': 2.998},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 339,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:26:19.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -109,
#      'sf': 10,
#      'snr': 8.8,
#      'snr_max': 17,
#      'snr_min': 3.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DJ1kN-R03vmj0LJ1Y',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:26:20.299Z',
#      'data': 'fc000105600bb60122',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 1,
#       'status': False,
#       'temperature': 34,
#       'voltage': 2.998},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 339,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:26:19.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -107,
#      'sf': 10,
#      'snr': 13,
#      'snr_max': 18,
#      'snr_min': 10,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DJ1jb-R03vmj0LJ1X',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:26:20.250Z',
#      'data': 'fc000105600bb60122',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 1,
#       'status': False,
#       'temperature': 34,
#       'voltage': 2.998},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 339,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:26:19.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -95,
#      'sf': 10,
#      'snr': 19.5,
#      'snr_max': 26.3,
#      'snr_min': 15.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DJ1ht-R03vmj0LJ1W',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923400000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:26:20.140Z',
#      'data': 'fc000105600bb60122',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 1,
#       'status': False,
#       'temperature': 34,
#       'voltage': 2.998},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 339,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:26:19.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -82,
#      'sf': 10,
#      'snr': 19.5,
#      'snr_max': 29.5,
#      'snr_min': 17,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DGmYb-R03vmj0LJpq',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:12:11.674Z',
#      'data': 'fc000105610bbeef21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 239,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 337,
#      'gwid': '00001c497b0b7ce3',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:11:02.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -115,
#      'sf': 10,
#      'snr': -8,
#      'snr_max': -5,
#      'snr_min': -12.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DGmVb-R03vmj0LJpo',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:12:11.482Z',
#      'data': 'fc000105610bbeef21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 239,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 337,
#      'gwid': '00001c497bc0de2b',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:12:11.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -109,
#      'sf': 10,
#      'snr': 4.5,
#      'snr_max': 8.3,
#      'snr_min': 0,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DGmVF-R03vmj0LJpn',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:12:11.460Z',
#      'data': 'fc000105610bbeef21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 239,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 337,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:12:11.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -132,
#      'sf': 10,
#      'snr': -15,
#      'snr_max': -11.8,
#      'snr_min': -18,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DGlkH-R03vmj0LJpl',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:12:08.326Z',
#      'data': 'fc000105610bbeef21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 239,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 337,
#      'gwid': '00001c497b0b7ce3',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:10:59.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -112.2,
#      'sf': 10,
#      'snr': -1.2,
#      'snr_max': 0.5,
#      'snr_min': -3.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DGliM-R03vmj0LJpk',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:12:08.203Z',
#      'data': 'fc000105610bbeef21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 239,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 337,
#      'gwid': '00001c497bc0de2b',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:12:07.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -112,
#      'sf': 10,
#      'snr': 3.8,
#      'snr_max': 8.3,
#      'snr_min': 1.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DGlh7-R03vmj0LJpj',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:12:08.186Z',
#      'data': 'fc000105610bbeef21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 239,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 337,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:12:07.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -119.2,
#      'sf': 10,
#      'snr': -5.2,
#      'snr_max': -2.2,
#      'snr_min': -7.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2DGlgS-R03vmj0LJpi',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T08:12:08.080Z',
#      'data': 'fc000105610bbeef21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 239,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 337,
#      'gwid': '00001c497b432024',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T08:12:07.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -117.8,
#      'sf': 10,
#      'snr': -4.8,
#      'snr_max': -2.8,
#      'snr_min': -7,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2C59vG-R03vmj0LI_3',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 924375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T07:16:59.461Z',
#      'data': 'fc000105600baa0020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.986},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 335,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T07:16:59.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -94,
#      'sf': 10,
#      'snr': 10,
#      'snr_max': 34.5,
#      'snr_min': -5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2C59uM-R03vmj0LI_2',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 924375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T07:16:59.403Z',
#      'data': 'fc000105600baa0020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.986},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 335,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T07:16:59.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -107,
#      'sf': 10,
#      'snr': 15.5,
#      'snr_max': 20.5,
#      'snr_min': 14.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2C59tw-R03vmj0LI_1',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 924375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T07:16:59.375Z',
#      'data': 'fc000105600baa0020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.986},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 335,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T07:15:50.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -89,
#      'sf': 10,
#      'snr': 23,
#      'snr_max': 28.8,
#      'snr_min': 17,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2C59tU-R03vmj0LI_0',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 924375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T07:16:59.347Z',
#      'data': 'fc000105600baa0020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.986},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 335,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T07:16:59.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -105,
#      'sf': 10,
#      'snr': 12.5,
#      'snr_max': 20,
#      'snr_min': 0,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2C586s-R03vmj0LI_y',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T07:16:56.107Z',
#      'data': 'fc000105600baa0020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.986},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 335,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T07:16:55.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -96,
#      'sf': 10,
#      'snr': 28.8,
#      'snr_max': 33,
#      'snr_min': 24.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2C586J-R03vmj0LI_x',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T07:16:56.072Z',
#      'data': 'fc000105600baa0020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.986},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 335,
#      'gwid': '00001c497b0b7ce3',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T07:15:47.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -95,
#      'sf': 10,
#      'snr': 30,
#      'snr_max': 37,
#      'snr_min': 19.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2C5855-R03vmj0LI_w',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T07:16:56.056Z',
#      'data': 'fc000105600baa0020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.986},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 335,
#      'gwid': '00001c497bc0de2b',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T07:16:55.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -89,
#      'sf': 10,
#      'snr': 27.5,
#      'snr_max': 38.8,
#      'snr_min': 24.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2C585h-R03vmj0LI_v',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T07:16:56.032Z',
#      'data': 'fc000105600baa0020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.986},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 335,
#      'gwid': '00001c497b432024',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T07:16:55.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -100,
#      'sf': 10,
#      'snr': 17,
#      'snr_max': 21.2,
#      'snr_min': 11.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CpqFr-R03vmj0LITb',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925875000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T06:05:44.681Z',
#      'data': 'fc000105610bc0ff20',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 32,
#       'voltage': 3.008},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 333,
#      'gwid': '00001c497b0b7ce3',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T06:04:35.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -111.5,
#      'sf': 10,
#      'snr': -2.5,
#      'snr_max': 0.2,
#      'snr_min': -5.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CpqDB-R03vmj0LITa',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925875000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T06:05:44.512Z',
#      'data': 'fc000105610bc0ff20',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 32,
#       'voltage': 3.008},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 333,
#      'gwid': '00001c497bc0de2b',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T06:05:43.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -106,
#      'sf': 10,
#      'snr': 13.8,
#      'snr_max': 18.8,
#      'snr_min': 12,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CpqBs-R03vmj0LITZ',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925875000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T06:05:44.426Z',
#      'data': 'fc000105610bc0ff20',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 32,
#       'voltage': 3.008},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 333,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T06:05:43.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -121.5,
#      'sf': 10,
#      'snr': -6.5,
#      'snr_max': -4.2,
#      'snr_min': -8.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CpqBF-R03vmj0LITY',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925875000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T06:05:44.387Z',
#      'data': 'fc000105610bc0ff20',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 32,
#       'voltage': 3.008},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 333,
#      'gwid': '00001c497b432024',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T06:05:43.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -116.8,
#      'sf': 10,
#      'snr': -2.8,
#      'snr_max': -1.2,
#      'snr_min': -5.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CppTU-R03vmj0LITW',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 924125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T06:05:41.458Z',
#      'data': 'fc000105610bc0ff20',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 32,
#       'voltage': 3.008},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 333,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T06:04:32.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -116.2,
#      'sf': 10,
#      'snr': -14.2,
#      'snr_max': -9,
#      'snr_min': -19.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CppQ2-R03vmj0LITV',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 924125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T06:05:41.301Z',
#      'data': 'fc000105610bc0ff20',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 32,
#       'voltage': 3.008},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 333,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T06:05:40.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -123.8,
#      'sf': 10,
#      'snr': -8.8,
#      'snr_max': -7,
#      'snr_min': -11.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CppN3-R03vmj0LITU',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 924125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T06:05:41.110Z',
#      'data': 'fc000105610bc0ff20',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 32,
#       'voltage': 3.008},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 333,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T06:05:40.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -103,
#      'sf': 10,
#      'snr': 3.3,
#      'snr_max': 10.8,
#      'snr_min': -3.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CoRaV-R03vmj0LIQJ',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T05:59:41.460Z',
#      'data': 'fc000105600bac001f',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 31,
#       'voltage': 2.988},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 331,
#      'gwid': '00001c497bc0de2b',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T05:59:40.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -90,
#      'sf': 10,
#      'snr': 25.8,
#      'snr_max': 33.8,
#      'snr_min': 20.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CoRZ8-R03vmj0LIQI',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T05:59:41.434Z',
#      'data': 'fc000105600bac001f',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 31,
#       'voltage': 2.988},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 331,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T05:59:40.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -97,
#      'sf': 10,
#      'snr': 23,
#      'snr_max': 30,
#      'snr_min': 17,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CoRZC-R03vmj0LIQH',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T05:59:41.377Z',
#      'data': 'fc000105600bac001f',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 31,
#       'voltage': 2.988},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 331,
#      'gwid': '00001c497b0b7ce3',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T05:58:32.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -91,
#      'sf': 10,
#      'snr': 18.8,
#      'snr_max': 28,
#      'snr_min': 14.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CoRYo-R03vmj0LIQG',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T05:59:41.351Z',
#      'data': 'fc000105600bac001f',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 31,
#       'voltage': 2.988},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 331,
#      'gwid': '00001c497b432024',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T05:59:40.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -119.2,
#      'sf': 10,
#      'snr': -8.2,
#      'snr_max': -4.2,
#      'snr_min': -13.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CoQtX-R03vmj0LIQD',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926875000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T05:59:38.582Z',
#      'data': 'fc000105600bac001f',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 31,
#       'voltage': 2.988},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 331,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T05:59:37.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -98,
#      'sf': 10,
#      'snr': 24.5,
#      'snr_max': 30.5,
#      'snr_min': 17,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CoQkz-R03vmj0LIQC',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926875000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T05:59:38.034Z',
#      'data': 'fc000105600bac001f',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 31,
#       'voltage': 2.988},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 331,
#      'gwid': '00001c497bc0de2b',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T05:59:37.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -90,
#      'sf': 10,
#      'snr': 25,
#      'snr_max': 33.3,
#      'snr_min': 15.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CoQke-R03vmj0LIQB',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926875000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T05:59:38.013Z',
#      'data': 'fc000105600bac001f',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 31,
#       'voltage': 2.988},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 331,
#      'gwid': '00001c497b0b7ce3',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T05:58:29.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -95,
#      'sf': 10,
#      'snr': 19.5,
#      'snr_max': 25.5,
#      'snr_min': 15.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CoQkO-R03vmj0LIQA',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926875000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T05:59:37.997Z',
#      'data': 'fc000105600bac001f',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 31,
#       'voltage': 2.988},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 331,
#      'gwid': '00001c497b432024',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T05:59:37.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -111,
#      'sf': 10,
#      'snr': -4,
#      'snr_max': -1.2,
#      'snr_min': -7,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CJTkF-R03vmj0LHOj',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:44:23.811Z',
#      'data': 'fc000105610bbaff21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.002},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 329,
#      'gwid': '00001c497b0b7ce3',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:43:14.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -120.8,
#      'sf': 10,
#      'snr': -8.8,
#      'snr_max': -4.8,
#      'snr_min': -18.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CJTgA-R03vmj0LHOi',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:44:23.550Z',
#      'data': 'fc000105610bbaff21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.002},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 329,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:44:23.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -124.8,
#      'sf': 10,
#      'snr': -10.8,
#      'snr_max': -9,
#      'snr_min': -14.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CJTdI-R03vmj0LHOh',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:44:23.366Z',
#      'data': 'fc000105610bbaff21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.002},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 329,
#      'gwid': '00001c497bc0de2b',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:44:22.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -105,
#      'sf': 10,
#      'snr': 14.5,
#      'snr_max': 20.8,
#      'snr_min': 10.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CJTcC-R03vmj0LHOg',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:44:23.296Z',
#      'data': 'fc000105610bbaff21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.002},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 329,
#      'gwid': '00001c497b432024',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:44:23.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -119,
#      'sf': 10,
#      'snr': -5,
#      'snr_max': -1.5,
#      'snr_min': -9.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CJStp-R03vmj0LHOe',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:44:20.327Z',
#      'data': 'fc000105610bbaff21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.002},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 329,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:44:19.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -123.2,
#      'sf': 10,
#      'snr': -8.2,
#      'snr_max': -5.5,
#      'snr_min': -10.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CJSoq-R03vmj0LHOc',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:44:20.008Z',
#      'data': 'fc000105610bbaff21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.002},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 329,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:44:19.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -120.5,
#      'sf': 10,
#      'snr': -6.5,
#      'snr_max': -4.5,
#      'snr_min': -10.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CJSn9-R03vmj0LHOb',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923600000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:44:19.963Z',
#      'data': 'fc000105610bbaff21',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 33,
#       'voltage': 3.002},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 329,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:44:19.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -101,
#      'sf': 10,
#      'snr': 13.8,
#      'snr_max': 20,
#      'snr_min': 7,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CIaVd-R03vmj0LHMj',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:40:29.404Z',
#      'data': 'fc000105600bb00020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 327,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:40:28.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -95,
#      'sf': 10,
#      'snr': 27,
#      'snr_max': 31.3,
#      'snr_min': 23.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CIaTy-R03vmj0LHMi',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:40:29.297Z',
#      'data': 'fc000105600bb00020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 327,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:40:28.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -102,
#      'sf': 10,
#      'snr': 18,
#      'snr_max': 23,
#      'snr_min': 10.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CIaTp-R03vmj0LHMh',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923400000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:40:29.287Z',
#      'data': 'fc000105600bb00020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 327,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:40:28.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -84,
#      'sf': 10,
#      'snr': 21.2,
#      'snr_max': 29.5,
#      'snr_min': 15.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CIaTb-R03vmj0LHMg',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:40:29.273Z',
#      'data': 'fc000105600bb00020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 327,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:39:20.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -95,
#      'sf': 10,
#      'snr': 21.2,
#      'snr_max': 27,
#      'snr_min': 15.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CIZhx-R03vmj0LHMe',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:40:26.095Z',
#      'data': 'fc000105600bb00020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 327,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:39:17.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -102.5,
#      'sf': 10,
#      'snr': -0.5,
#      'snr_max': 5,
#      'snr_min': -5.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CIZge-R03vmj0LHMd',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:40:26.012Z',
#      'data': 'fc000105600bb00020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 327,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-27T03:40:25.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -96,
#      'sf': 10,
#      'snr': 22,
#      'snr_max': 32,
#      'snr_min': 15.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2CIZgQ-R03vmj0LHMc',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-27T03:40:25.998Z',
#      'data': 'fc000105600bb00020',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 0,
#       'status': False,
#       'temperature': 32,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 327,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
# ...
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 115,
#      'gwid': '00001c497b5eef36',
#      'gwip': '192.168.11.9',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T10:07:35.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -92,
#      'sf': 10,
#      'snr': 29.5,
#      'snr_max': 35,
#      'snr_min': 27.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0H620f-R03vmj0Hasw',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T10:07:35.710Z',
#      'data': 'fc000105600bbe081b',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 8,
#       'status': False,
#       'temperature': 27,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 115,
#      'gwid': '00001c497b48dc3e',
#      'gwip': '10.5.181.43',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T10:07:35.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -93,
#      'sf': 10,
#      'snr': 23.3,
#      'snr_max': 30.8,
#      'snr_min': 19.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0H620D-R03vmj0Hasv',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T10:07:35.682Z',
#      'data': 'fc000105600bbe081b',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 8,
#       'status': False,
#       'temperature': 27,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 115,
#      'gwid': '00001c497b48dc69',
#      'gwip': '10.5.180.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T10:07:35.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -136.5,
#      'sf': 10,
#      'snr': -15.5,
#      'snr_max': -13.8,
#      'snr_min': -18.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0H62xr-R03vmj0Hasu',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T10:07:35.530Z',
#      'data': 'fc000105600bbe081b',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 8,
#       'status': False,
#       'temperature': 27,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 115,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T10:07:35.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -93,
#      'sf': 10,
#      'snr': 28,
#      'snr_max': 36.2,
#      'snr_min': 23,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0H62xp-R03vmj0Hast',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T10:07:35.528Z',
#      'data': 'fc000105600bbe081b',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 8,
#       'status': False,
#       'temperature': 27,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 115,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T10:06:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -95,
#      'sf': 10,
#      'snr': 8.8,
#      'snr_max': 23.8,
#      'snr_min': 5.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0H62xM-R03vmj0Hass',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T10:07:35.499Z',
#      'data': 'fc000105600bbe081b',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 8,
#       'status': False,
#       'temperature': 27,
#       'voltage': 3.006},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 115,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T10:07:35.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -108,
#      'sf': 10,
#      'snr': 12,
#      'snr_max': 17,
#      'snr_min': 9.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI79c-R03vmj0HYtr',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:52.347Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497b5eeeec',
#      'gwip': '192.168.11.9',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -113.2,
#      'sf': 10,
#      'snr': -1.2,
#      'snr_max': 0.2,
#      'snr_min': -3.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI74W-R03vmj0HYtq',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:52.021Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497b48db93',
#      'gwip': '10.5.201.36',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -116.5,
#      'sf': 10,
#      'snr': -5.5,
#      'snr_max': -4,
#      'snr_min': -7.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI72E-R03vmj0HYtp',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:51.874Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497bc0de2b',
#      'gwip': '10.5.180.17',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -120,
#      'sf': 10,
#      'snr': -5,
#      'snr_max': -3.5,
#      'snr_min': -9,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI711-R03vmj0HYto',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:51.859Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497b432024',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -126.8,
#      'sf': 10,
#      'snr': -11.8,
#      'snr_max': -10,
#      'snr_min': -16,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI71K-R03vmj0HYtn',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926625000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:51.817Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -119,
#      'sf': 10,
#      'snr': -7,
#      'snr_max': -4.8,
#      'snr_min': -9.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI7q1-R03vmj0HYtm',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:51.156Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:48.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -124.8,
#      'sf': 10,
#      'snr': -9.8,
#      'snr_max': -8.8,
#      'snr_min': -13.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI7J0-R03vmj0HYtk',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:49.043Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497b5eeeec',
#      'gwip': '192.168.11.9',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:48.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -108,
#      'sf': 10,
#      'snr': 10,
#      'snr_max': 15.5,
#      'snr_min': 7.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI7Dr-R03vmj0HYtj',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:48.650Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497b48db93',
#      'gwip': '10.5.201.36',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:48.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -122,
#      'sf': 10,
#      'snr': -9,
#      'snr_max': -8.5,
#      'snr_min': -13,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI7C1-R03vmj0HYti',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:48.596Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497bc0de2b',
#      'gwip': '10.5.180.17',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:48.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -118,
#      'sf': 10,
#      'snr': -3,
#      'snr_max': -2.3,
#      'snr_min': -5.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI7Cr-R03vmj0HYth',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:48.586Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497b0b7ce3',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:04.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -111.5,
#      'sf': 10,
#      'snr': -3.5,
#      'snr_max': -0.2,
#      'snr_min': -8.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0GI7CS-R03vmj0HYtg',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T01:49:48.560Z',
#      'data': 'fc000105630bb0ff19',
#      'dataParse': {'keepAlive': True,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 2.992},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 113,
#      'gwid': '00001c497b432024',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T01:49:48.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -130.8,
#      'sf': 10,
#      'snr': -10.8,
#      'snr_max': -8.2,
#      'snr_min': -16.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV0F8XYf-R03vmj0HYgj',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 924125000,
#      'commsysType': 'lora',
#      'create_at': '2017-07-03T00:54:56.798Z',
#      'data': 'fc000105610bceff19',
#      'dataParse': {'keepAlive': False,
#       'lowBattery': False,
#       'mdi': 255,
#       'status': True,
#       'temperature': 25,
#       'voltage': 3.022},
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '正文009',
#       'type': 'node'},
#      'fport': 2,
#      'frameCnt': 111,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d0100ab',
#      'recv': '2017-07-03T00:54:09.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -115.5,
#      'sf': 10,
#      'snr': -9.5,
#      'snr_max': -7.2,
#      'snr_min': -11.8,
#      'systype': 13},
#     '_type': 'parking_record_type'}],
#   'max_score': None,
#   'total': 1899}}

# %% [markdown]
# ## Data prasing
#  1. lattency

# %%
#-*- coding=utf-8 -*-
import requests
import json
import time
import hashlib
import pandas as pd
from datetime import datetime
import matplotlib as plt

df = pd.read_csv(csvFileName, encoding='utf_8_sig')
df.head(5)

df['create_at_time'] 
df['recv_at_time']
# Out:
#    Unnamed: 0                   _id                   _index  \
# 0           0  AV197R2L-R03vmj0K7en  parking_record_index_v2
# 1           1  AV197Q3r-R03vmj0K7ei  parking_record_index_v2
# 2           2  AV197P5A-R03vmj0K7ef  parking_record_index_v2
# 3           3  AV197O6a-R03vmj0K7eU  parking_record_index_v2
# 4           4  AV197N8V-R03vmj0K7eR  parking_record_index_v2
#
#              create_at_time              recv_at_time                    data  \
# 0  2017-07-26T08:04:37.898Z  2017-07-26T08:04:37.000Z  fcffff072d001100f4001c
# 1  2017-07-26T08:04:33.897Z  2017-07-26T08:04:33.000Z  fcffff072f000b00f8001c
# 2  2017-07-26T08:04:29.887Z  2017-07-26T08:04:29.000Z  fcffff072f000b00f8001c
# 3  2017-07-26T08:04:25.881Z  2017-07-26T08:04:25.000Z  fcffff072f000b00f8001c
# 4  2017-07-26T08:04:21.908Z  2017-07-26T08:04:21.000Z  fcffff072f000b00f8001c
#
#   company      road  slot_num        gwip  magX  magY  magZ  magT
# 0   yilan  宜蘭市中山路二段       111  10.5.151.1    45    17   244    28
# 1   yilan  宜蘭市中山路二段       111  10.5.151.1    47    11   248    28
# 2   yilan  宜蘭市中山路二段       111  10.5.151.1    47    11   248    28
# 3   yilan  宜蘭市中山路二段       111  10.5.151.1    47    11   248    28
# 4   yilan  宜蘭市中山路二段       111  10.5.151.1    47    11   248    28

# %%
from datetime import datetime

datetime_object = datetime.strptime('Jun 1 2005  1:33PM', '%b %d %Y %I:%M%p')
# Out:
# datetime.datetime(2005, 6, 1, 13, 33)

# %%
datetime_object = datetime.strptime('2017-07-26T08:04:33.897Z', '%Y-%m-%d %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-9a5a8b02f5d1> in <module>()
# ----> 1 datetime_object = datetime.strptime('2017-07-26T08:04:33.897Z', '%Y-%m-%d %H:%M:%S')
#
# /Users/MH/anaconda/envs/py36/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# /Users/MH/anaconda/envs/py36/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '2017-07-26T08:04:33.897Z' does not match format '%Y-%m-%d %H:%M:%S'
