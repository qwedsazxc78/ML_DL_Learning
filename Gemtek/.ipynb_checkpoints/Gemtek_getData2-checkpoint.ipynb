# %% [markdown]
# ## Main function test

# %%
#-*- coding=utf-8 -*-
import requests
import json
import time
import hashlib
import pandas as pd
from datetime import datetime

URL = "https://s5.securepilot.com/parking/v1/query_record"
api_key = "PARK-eMPpua7y17"
api_secret = "2PHIAGI5qv5IhMGZ56iy"

mac_gemtek = "101a"
mac_address1 = mac_gemtek + "0d0100ab"
mac_address_test = mac_gemtek + "0d01019a"

def byteToMagData(Low_byte, High_byte):
    return twos_comp(byte2SwapToNumber(Low_byte,High_byte), 16)

def byte2SwapToNumber(Low_byte, High_byte):
    return int(Low_byte.encode(), 16) + int(High_byte.encode(), 16) * 256

def twos_comp(val, bits):
    """compute the 2's complement of int value val"""
    if (val & (1 << (bits - 1))) != 0: # if sign bit is set e.g., 8bit: 128-255
        val = val - (1 << bits)        # compute negative value
    return val 

def getParkDataResponse(URL, api_key, api_secret, macID):
    current_unix_time = str(int(time.time()))
    api_token = hashlib.sha1((api_secret + current_unix_time).encode('utf-8')).hexdigest()
    index = 0
    limit = 2
    print("------------- RESTful API parameter --------------")
    print("mac: ", macID)
    print("api_key: ", api_key)
    print("api_secret: ", api_secret)
    print("unix_time: ", current_unix_time)
    print("api_token: ", api_token)
    print("index: ", index, "limit: ", limit)
    print("--------------------------------------------------\n")

    if len(macID) != 12:
        print("mac address is ilegal !!")

#     payload = { "index" : 1, "limit" : 20, "mac" : macID, 
#            "api_key" : api_key, "api_token" : api_token, "time" : current_unix_time
#            }
#     payload = {
#         'mac' : macID, 
#         'api_key' : api_key, 
#         'api_token' : api_token, 
#         'time' : current_unix_time 
#     }
    
    payload = {
        "index": index,
        "limit" : limit,
        "mac" : "101a0d01019a",
        "api_key" : "PARK-eMPpua7y17",
        "api_token" : "7a5db58d81e51ce9cb5a7731d6c6b7fa1bb0144a",
        "time" : "1500874971"
    }
    print("------------- Payload Check ----------------------")
    print("Payload:", payload)
    print("--------------------------------------------------\n")

#     return requests.post(URL, data = payload)
    return requests.post(URL, json = payload)

def getPraseTargetData(req):
    prase_data = prase_data['value']['hits']
    
    prase_data_from_json = []
    # columes in data frame
    prase_data_columes = ['_id', '_index', 'create_at_time','recv_at_time','data',
                          'company','road','slot_num','gwip', 
                          "magX", "magY", "magZ", "magT"]
    # get data by list
    for each in prase_data:
        fullData = []
        pakcetHeader = "fcffff07"
        packetByte = []
        
        fullData = [ each['_id'], each['_index'], 
             each['_source']['create_at'], each['_source']['recv'],
             each['_source']['data'],
             each['_source']['extra']['company'],  each['_source']['extra']['road'], 
             each['_source']['extra']['slot_num'], each['_source']['gwip']
        ]
        
        # get high/ low byte
        packetMagData = each['_source']['data']
        
        if packetMagData.find(pakcetHeader) != -1:
            index = [i for i in range(len(packetMagData)) if i % 2 == 0]   
            for each in index:
                packetByte.append(packetMagData[each:each+2])
#             print("packet Byte: ", packetByte)
        else:
            print("packet header error")

        magX = byteToMagData(packetByte[4], packetByte[5])
        magY = byteToMagData(packetByte[6], packetByte[7])
        magZ = byteToMagData(packetByte[8], packetByte[9])
        magT = byteToMagData(packetByte[10], '00')
        
        fullData.extend([magX, magY, magZ, magT])
        print("Data:", fullData)
        prase_data_from_json.append(fullData)
       
    return pd.DataFrame(prase_data_from_json, columns=prase_data_columes) 


# main funciton
req = getParkDataResponse(URL, api_key, api_secret, mac_address_test)
server_ReturnCode = req.json()['status']['code']
server_ReturnMsg = req.json()['status']['message']

if(req.ok and server_ReturnCode == 1200):
    print("------------- Request Status ---------------------")
    print("Request URL: ",req.url, ", Status: OK ")
    print("--------------------------------------------------\n")
    
    df = getPraseTargetData(req)
    NodeName = df['slot_num'][0]
    timeName = datetime.now().strftime('%Y%m%d_%H%M%S')
    csvFileName = timeName + '_' + NodeName + '.csv'
    df.to_csv(csvFileName, encoding='utf_8_sig')
else:
     print("Status: FAIL , Server return code ",server_ReturnCode, ", Msg :", server_ReturnMsg)
    
# #     print(req.text)
# Out:
# ------------- RESTful API parameter --------------
# mac:  101a0d01019a
# api_key:  PARK-eMPpua7y17
# api_secret:  2PHIAGI5qv5IhMGZ56iy
# unix_time:  1501139831
# api_token:  118dba38cfed8b07d99c576cb04b9ebefb70537c
# index:  0 limit:  2
# --------------------------------------------------
#
# ------------- Payload Check ----------------------
# Payload: {'index': 0, 'limit': 2, 'mac': '101a0d01019a', 'api_key': 'PARK-eMPpua7y17', 'api_token': '7a5db58d81e51ce9cb5a7731d6c6b7fa1bb0144a', 'time': '1500874971'}
# --------------------------------------------------
#
# ------------- Request Status ---------------------
# Request URL:  https://s5.securepilot.com/parking/v1/query_record , Status: OK
# --------------------------------------------------
#
# Data: ['AV197R2L-R03vmj0K7en', 'parking_record_index_v2', '2017-07-26T08:04:37.898Z', '2017-07-26T08:04:37.000Z', 'fcffff072d001100f4001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 45, 17, 244, 28]
# Data: ['AV197Q3r-R03vmj0K7ei', 'parking_record_index_v2', '2017-07-26T08:04:33.897Z', '2017-07-26T08:04:33.000Z', 'fcffff072f000b00f8001c', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 47, 11, 248, 28]

# %% [markdown]
# ## API Class

# %%
from datetime import datetime
import hashlib

class Gemtek_restful_api:
    def __init__(self, URL, api_key, api_secret, macID, index = 0, limit = 10, start_time = 0):
        self.URL = URL
        self.api_key = api_key
        self.api_secret = api_secret
        self.macID = macID
        self.index = index
        self.limit = limit
        self.time = str(int(time.time()))
        self.start_time  = 0
        self.api_token = hashlib.sha1((self.api_secret + self.time).encode('utf-8')).hexdigest()
        self.payload = {
            "index": self.index,
            "start_time" : self.start_time,
            "time" : self.time,
            "mac" : self.macID,
            "api_key" : self.api_key,
            "api_token" : self.api_token,
            "time" : self.time
        }
        self.jsonData = None
        self.request_OK = None
        if len(macID) != 12:
            print("mac address is ilegal !!")
        
    def set_query_index(self, index = 0):
        self.index = index

    def set_query_limit(self, limit = 10):
        self.limit = limit
        
    def set_query_start_time(self, start_time = 0):
        self.start_time = start_time

    def print_API_parameter(self):
        print("------------- RESTful API parameter --------------")
        print("mac: ", self.macID)
        print("api_key: ", self.api_key)
        print("api_secret: ", self.api_secret)
        print("unix_time: ", self.time)
        print("api_token: ", self.api_token)
        print("index: ", self.index, "limit: ", self.limit, "start_time", self.start_time)
        print("Payload:", self.payload)
        print("--------------------------------------------------\n")
        
    def get_query_data(self):    
        req = requests.post(self.URL, json = self.payload)
        self.jsonData = req.json()
        server_ReturnCode = self.jsonData['status']['code']
        server_ReturnMsg = self.jsonData['status']['message']
        if (server_ReturnCode == 1200):
            self.request_OK = True
        else:
            self.request_OK = False
        
        print("------------- Request Status ---------------------")
        print("Request URL: ", req.url)
        print("Server return code ",server_ReturnCode, ", Msg :", server_ReturnMsg)
        print("--------------------------------------------------\n")
     
        return self.jsonData
    
    def update_new_api_token(self):    
        self.time = str(int(time.time()))
        self.api_token = hashlib.sha1((self.api_secret + self.time).encode('utf-8')).hexdigest()
        self.payload["time"] = self.time
        self.payload["api_token"] = self.api_token

# %%
# test_api = Gemtek_restful_api(URL, api_key, api_secret, mac_address_test)
# test_api.print_API_parameter()
# query_JsonData = test_api.get_query_data()

# %%
from time import mktime
from datetime import datetime

current_time_obj = time.time()
current_datetime_obj = datetime.fromtimestamp(current_time_obj)
current_time = int(current_time_obj)
print(current_time)
# Out:
# 1501577268

# %%
#-*- coding=utf-8 -*-
import requests
import json
import time
import hashlib
import pandas as pd
from datetime import datetime
from time import mktime
from datetime import datetime

URL = "https://s5.securepilot.com/parking/v1/query_record"
api_key = "PARK-eMPpua7y17"
api_secret = "2PHIAGI5qv5IhMGZ56iy"

mac_gemtek = "101a"
mac_address1 = "0d0100ab"
mac_address_test = "0d01019a"

mac_query = mac_gemtek + mac_address_test

def byteToMagData(Low_byte, High_byte):
    value = int(Low_byte.encode(), 16) + int(High_byte.encode(), 16) * 256
    return twos_comp(value, 16)

def twos_comp(val, bits):
    """compute the 2's complement of int value val"""
    if (val & (1 << (bits - 1))) != 0: # if sign bit is set e.g., 8bit: 128-255
        val = val - (1 << bits)        # compute negative value
    return val 

def getPraseTargetData(Data):
    prase_data = Data['value']['hits']
    prase_data_from_json = []
    
    # columes in data frame
    prase_data_columes = ['_id', '_index', 'mac','create_at_time','recv_at_time','frameCnt', 'data',
                          'company','road','slot_num','gwip', 
                          "magX", "magY", "magZ", "magT"]
    # get data by list
    for each in prase_data:
        fullData = []
        pakcetHeader = "fcffff07"
        packetByte = []
        
        fullData = [ each['_id'], each['_index'], each['_source']['macAddr'],
             each['_source']['create_at'], each['_source']['recv'], each['_source']['frameCnt'],
             each['_source']['data'], 
             each['_source']['extra']['company'],  each['_source']['extra']['road'], 
             each['_source']['extra']['slot_num'], each['_source']['gwip']
        ]
        
        # get high/ low byte
        packetMagData = each['_source']['data']
        
        if packetMagData.find(pakcetHeader) != -1:
            index = [i for i in range(len(packetMagData)) if i % 2 == 0]   
            for each in index:
                packetByte.append(packetMagData[each:each+2])
#             print("packet Byte: ", packetByte)
        else:
            print("packet header error")

        magX = byteToMagData(packetByte[4], packetByte[5])
        magY = byteToMagData(packetByte[6], packetByte[7])
        magZ = byteToMagData(packetByte[8], packetByte[9])
        magT = byteToMagData(packetByte[10], '00')
        
        fullData.extend([magX, magY, magZ, magT])
        print("Data:", fullData)
        prase_data_from_json.append(fullData)
       
    return pd.DataFrame(prase_data_from_json, columns=prase_data_columes) 

# main funciton
test_api = Gemtek_restful_api(URL, api_key, api_secret, mac_query, index = 0 , limit = 200, start_time = current_time)
test_api.print_API_parameter()
query_JsonData = test_api.get_query_data()

if(test_api.request_OK):
    df = getPraseTargetData(query_JsonData)
    NodeName = mac_query
    timeName = current_datetime_obj.strftime('%Y%m%d_%H%M%S')
    csvFileName = 'ID_' + NodeName + '_' + timeName + '.csv'
    df.to_csv(csvFileName, encoding='utf_8_sig')
else:
    print("Status: FAIL , Server return code ",server_ReturnCode, ", Msg :", server_ReturnMsg)
    
# #     print(req.text)
# Out:
# ------------- RESTful API parameter --------------
# mac:  101a0d01019a
# api_key:  PARK-eMPpua7y17
# api_secret:  2PHIAGI5qv5IhMGZ56iy
# unix_time:  1501577269
# api_token:  a3ae65cf468d1d484df896c33ad8a1d1cdcf2baf
# index:  0 limit:  200 start_time 0
# Payload: {'index': 0, 'start_time': 0, 'time': '1501577269', 'mac': '101a0d01019a', 'api_key': 'PARK-eMPpua7y17', 'api_token': 'a3ae65cf468d1d484df896c33ad8a1d1cdcf2baf'}
# --------------------------------------------------
#
# ------------- Request Status ---------------------
# Request URL:  https://s5.securepilot.com/parking/v1/query_record
# Server return code  1200 , Msg : Command succeeded
# --------------------------------------------------
#
# Data: ['AV2czgGy-R03vmj0MBst', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:52.849Z', '2017-08-01T07:58:52.000Z', 24, 'fcffff0788ff34ff78ff1e', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', -120, -204, -136, 30]
# Data: ['AV2czfYc-R03vmj0MBsr', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:49.883Z', '2017-08-01T07:58:49.000Z', 23, 'fcffff0788fff7ff57ff1e', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', -120, -9, -169, 30]
# Data: ['AV2czepy-R03vmj0MBsp', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:46.897Z', '2017-08-01T07:58:46.000Z', 22, 'fcffff0739000c0027ff1e', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 57, 12, -217, 30]
# Data: ['AV2czd6m-R03vmj0MBsn', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:43.877Z', '2017-08-01T07:58:43.000Z', 21, 'fcffff07f9ff0c008dff1e', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', -7, 12, -115, 30]
# Data: ['AV2czdMA-R03vmj0MBsk', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:40.895Z', '2017-08-01T07:58:40.000Z', 20, 'fcffff076cffc4ffa5ff1e', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', -148, -60, -91, 30]
# Data: ['AV2czcdA-R03vmj0MBsi', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:37.887Z', '2017-08-01T07:58:37.000Z', 19, 'fcffff074800a4ffb1ff1e', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 72, -92, -79, 30]
# Data: ['AV2czbuC-R03vmj0MBsh', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:34.881Z', '2017-08-01T07:58:34.000Z', 18, 'fcffff07080011ffabff1e', 'yilan', '宜蘭市中山路二段', '111', '10.5.151.1', 8, -239, -85, 30]
# Data: ['AV2czakr-R03vmj0MBsc', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:30.186Z', '2017-08-01T07:58:29.000Z', 16, 'fcffff07a2ff48ffb0ff1e', 'yilan', '宜蘭市中山路二段', '111', '192.168.88.113', -94, -184, -80, 30]
# Data: ['AV2czagt-R03vmj0MBsa', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:29.932Z', '2017-08-01T07:58:29.000Z', 16, 'fcffff07a2ff48ffb0ff1e', 'yilan', '宜蘭市中山路二段', '111', '192.168.88.150', -94, -184, -80, 30]
# Data: ['AV2czafN-R03vmj0MBsZ', 'parking_record_index_v2', '101a0d01019a', '2017-08-01T07:58:29.836Z', '2017-08-01T07:58:29.000Z', 16, 'fcffff07a2ff48ffb0ff1e', 'yilan', '宜蘭市中山路二段', '111', '192.168.11.2', -94, -184, -80, 30]

# %%
datetime.now()
# Out:
# datetime.datetime(2017, 8, 1, 16, 43, 25, 589918)

# %%
time.time()
# Out:
# 1501577039.181712

# %%
query_JsonData
# Out:
# {'status': {'code': 1200, 'message': 'Command succeeded'},
#  'value': {'hits': [{'_id': 'AV2cuzmt-R03vmj0MBcL',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922400000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:21.996Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 205,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:21.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -52,
#      'sf': 10,
#      'snr': 27,
#      'snr_max': 35,
#      'snr_min': 20,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuzlp-R03vmj0MBcK',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:21.928Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 205,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:21.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -113.8,
#      'sf': 10,
#      'snr': -0.8,
#      'snr_max': 1.2,
#      'snr_min': -1.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuylD-R03vmj0MBcH',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:17.794Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 204,
#      'gwid': '00001c497bb44c6a',
#      'gwip': '192.168.88.113',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:17.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -105.3,
#      'sf': 10,
#      'snr': -0.3,
#      'snr_max': 3,
#      'snr_min': -2.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuygf-R03vmj0MBcG',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:17.502Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 204,
#      'gwid': '00001c497bb44bdc',
#      'gwip': '192.168.88.150',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:17.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -103,
#      'sf': 10,
#      'snr': 12.5,
#      'snr_max': 22,
#      'snr_min': 9.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuygY-R03vmj0MBcF',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:17.496Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 204,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:17.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -113,
#      'sf': 10,
#      'snr': 12.5,
#      'snr_max': 21.3,
#      'snr_min': 6.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuygO-R03vmj0MBcE',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:17.485Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 204,
#      'gwid': '00001c497bb44bb3',
#      'gwip': '192.168.11.2',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:17.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -97,
#      'sf': 10,
#      'snr': 19.5,
#      'snr_max': 25,
#      'snr_min': 13.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuygG-R03vmj0MBcD',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:17.477Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 204,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:03.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -107,
#      'sf': 10,
#      'snr': 14.5,
#      'snr_max': 20.5,
#      'snr_min': 5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuyfx-R03vmj0MBcC',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923400000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:17.456Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 204,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:17.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -53,
#      'sf': 10,
#      'snr': 27,
#      'snr_max': 34.5,
#      'snr_min': 20.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuyff-R03vmj0MBcB',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:17.438Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 204,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:17.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -61,
#      'sf': 10,
#      'snr': 18,
#      'snr_max': 30.5,
#      'snr_min': 12.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuyfN-R03vmj0MBcA',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:17.421Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 204,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:17.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -111,
#      'sf': 10,
#      'snr': 8.8,
#      'snr_max': 16.2,
#      'snr_min': 2.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuxeu-R03vmj0MBb-',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:13.293Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 203,
#      'gwid': '00001c497bb44bdc',
#      'gwip': '192.168.88.150',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:12.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -97,
#      'sf': 10,
#      'snr': 16.3,
#      'snr_max': 24.5,
#      'snr_min': 12,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuxeO-R03vmj0MBb9',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:13.262Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 203,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:12.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -99,
#      'sf': 10,
#      'snr': 12.5,
#      'snr_max': 22,
#      'snr_min': 3.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuxdy-R03vmj0MBb8',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:13.233Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 203,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:58.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -100.2,
#      'sf': 10,
#      'snr': -1.2,
#      'snr_max': 1.8,
#      'snr_min': -4,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuxds-R03vmj0MBb7',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:13.227Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 203,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:12.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -53,
#      'sf': 10,
#      'snr': 23.8,
#      'snr_max': 28.8,
#      'snr_min': 13.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuxdm-R03vmj0MBb6',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:13.221Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 203,
#      'gwid': '00001c497bb44bb3',
#      'gwip': '192.168.11.2',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:12.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -81,
#      'sf': 10,
#      'snr': 24.5,
#      'snr_max': 34.5,
#      'snr_min': 13.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuxdh-R03vmj0MBb5',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:13.216Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 203,
#      'gwid': '00001c497bb44c6a',
#      'gwip': '192.168.88.113',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:12.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -89,
#      'sf': 10,
#      'snr': 0.8,
#      'snr_max': 25,
#      'snr_min': -28.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuxci-R03vmj0MBb4',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:13.153Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 203,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:12.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -107,
#      'sf': 10,
#      'snr': 3,
#      'snr_max': 12,
#      'snr_min': -8.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuxZh-R03vmj0MBb3',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923600000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:12.960Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 203,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:12.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -54,
#      'sf': 10,
#      'snr': 32,
#      'snr_max': 38,
#      'snr_min': 29.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuwqX-R03vmj0MBb0',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920600000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:09.942Z',
#      'data': 'fcffff0786003000adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 202,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:09.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -43,
#      'sf': 10,
#      'snr': 25,
#      'snr_max': 37,
#      'snr_min': 18.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuv7L-R03vmj0MBbz',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920800000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:06.922Z',
#      'data': 'fcffff0786002f00adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 201,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:06.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -45,
#      'sf': 10,
#      'snr': 29.5,
#      'snr_max': 39.5,
#      'snr_min': 21.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuvMy-R03vmj0MBbx',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:03.953Z',
#      'data': 'fcffff0786002f00adff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 200,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:03.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -47,
#      'sf': 10,
#      'snr': 29.5,
#      'snr_max': 37.5,
#      'snr_min': 24.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuudz-R03vmj0MBbu',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921800000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:38:00.946Z',
#      'data': 'fcffff0786002f00acff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 199,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:38:00.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -51,
#      'sf': 10,
#      'snr': 29.5,
#      'snr_max': 35.5,
#      'snr_min': 25,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cutur-R03vmj0MBbs',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922000000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:57.930Z',
#      'data': 'fcffff0786002f00acff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 198,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:57.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -53,
#      'sf': 10,
#      'snr': 31.2,
#      'snr_max': 39.5,
#      'snr_min': 27.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cus_9-R03vmj0MBbr',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923800000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:54.940Z',
#      'data': 'fcffff0786002f00acff1d',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 197,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:54.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -57,
#      'sf': 10,
#      'snr': 22.5,
#      'snr_max': 36.2,
#      'snr_min': 19.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cusRZ-R03vmj0MBbn',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:51.960Z',
#      'data': 'fcffff0786002f00adff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 196,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -53,
#      'sf': 10,
#      'snr': 30,
#      'snr_max': 38.8,
#      'snr_min': 18,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuqzi-R03vmj0MBbl',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:45.953Z',
#      'data': 'fcffff0786002c00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 195,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:45.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -47,
#      'sf': 10,
#      'snr': 33,
#      'snr_max': 43.8,
#      'snr_min': 28,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuqIe-R03vmj0MBbj',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 924375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:43.197Z',
#      'data': 'fcffff0786002f00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 194,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:42.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -133.2,
#      'sf': 10,
#      'snr': -14.2,
#      'snr_max': -10.8,
#      'snr_min': -19,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuqE1-R03vmj0MBbh',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920400000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:42.964Z',
#      'data': 'fcffff0786002f00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 194,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:42.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -45,
#      'sf': 10,
#      'snr': 29.5,
#      'snr_max': 38,
#      'snr_min': 25,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cupV9-R03vmj0MBbc',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921000000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:39.964Z',
#      'data': 'fcffff0786002f00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 193,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:39.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -47,
#      'sf': 10,
#      'snr': 33,
#      'snr_max': 42.5,
#      'snr_min': 20,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuonP-R03vmj0MBbY',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:36.974Z',
#      'data': 'fcffff0786002f00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 192,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:36.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -116.5,
#      'sf': 10,
#      'snr': -3.5,
#      'snr_max': -1.8,
#      'snr_min': -4.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuomn-R03vmj0MBbX',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921400000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:36.935Z',
#      'data': 'fcffff0786002f00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 192,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:36.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -49,
#      'sf': 10,
#      'snr': 33.8,
#      'snr_max': 43,
#      'snr_min': 32,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cun3--R03vmj0MBbV',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921800000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:33.949Z',
#      'data': 'fcffff0786002f00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 191,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:33.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -51,
#      'sf': 10,
#      'snr': 29.5,
#      'snr_max': 38,
#      'snr_min': 23,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cunNJ-R03vmj0MBbS',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922000000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:31.208Z',
#      'data': 'fcffff0787003000abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 190,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:30.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -53,
#      'sf': 10,
#      'snr': 29.5,
#      'snr_max': 37.5,
#      'snr_min': 23,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cumaL-R03vmj0MBbQ',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:27.947Z',
#      'data': 'fcffff0786002f00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 189,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:27.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -114.5,
#      'sf': 10,
#      'snr': -1.5,
#      'snr_max': 0,
#      'snr_min': -2.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cumZm-R03vmj0MBbP',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922400000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:27.909Z',
#      'data': 'fcffff0786002f00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 189,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:27.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -52,
#      'sf': 10,
#      'snr': 28.8,
#      'snr_max': 35.5,
#      'snr_min': 24.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2culrD-R03vmj0MBbO',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:24.931Z',
#      'data': 'fcffff0786002e00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 188,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:24.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -55,
#      'sf': 10,
#      'snr': 34.5,
#      'snr_max': 42,
#      'snr_min': 30.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cukUQ-R03vmj0MBbJ',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:19.375Z',
#      'data': 'fcffff0786002e00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 187,
#      'gwid': '00001c497bb44bdc',
#      'gwip': '192.168.88.150',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:18.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -101,
#      'sf': 10,
#      'snr': 17.5,
#      'snr_max': 25,
#      'snr_min': 15,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cukQt-R03vmj0MBbI',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:19.148Z',
#      'data': 'fcffff0786002e00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 187,
#      'gwid': '00001c497bb44c6a',
#      'gwip': '192.168.88.113',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:18.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -93,
#      'sf': 10,
#      'snr': 12,
#      'snr_max': 17,
#      'snr_min': 7.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cukP3-R03vmj0MBbH',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:19.094Z',
#      'data': 'fcffff0786002e00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 187,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:18.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -109,
#      'sf': 10,
#      'snr': 10,
#      'snr_max': 14.5,
#      'snr_min': 5.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cukP0-R03vmj0MBbG',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:19.092Z',
#      'data': 'fcffff0786002e00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 187,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:18.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -52,
#      'sf': 10,
#      'snr': 21.2,
#      'snr_max': 30.5,
#      'snr_min': 17.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cukPo-R03vmj0MBbF',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:19.079Z',
#      'data': 'fcffff0786002e00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 187,
#      'gwid': '00001c497bb44bb3',
#      'gwip': '192.168.11.2',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:18.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -86,
#      'sf': 10,
#      'snr': 20,
#      'snr_max': 26.3,
#      'snr_min': 11.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cukO2-R03vmj0MBbE',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:19.029Z',
#      'data': 'fcffff0786002e00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 187,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:04.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -101,
#      'sf': 10,
#      'snr': 7.5,
#      'snr_max': 15.5,
#      'snr_min': -0.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cukNX-R03vmj0MBbD',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923600000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:18.934Z',
#      'data': 'fcffff0786002e00abff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 187,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:18.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -55,
#      'sf': 10,
#      'snr': 31.2,
#      'snr_max': 37,
#      'snr_min': 26.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuje7-R03vmj0MBa-',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920600000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:15.962Z',
#      'data': 'fcffff0786002e00aaff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 186,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:15.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -42,
#      'sf': 10,
#      'snr': 24.5,
#      'snr_max': 33.8,
#      'snr_min': 18.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuixv-R03vmj0MBa4',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921000000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:13.071Z',
#      'data': 'fcffff0786002e00aaff1e',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 185,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:12.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -48,
#      'sf': 10,
#      'snr': 33,
#      'snr_max': 39.5,
#      'snr_min': 29.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuiBe-R03vmj0MBa2',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:09.981Z',
#      'data': 'fcffff0786002d00a9ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 184,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:09.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -49,
#      'sf': 10,
#      'snr': 32,
#      'snr_max': 40.5,
#      'snr_min': 25,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuhSE-R03vmj0MBa0',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921800000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:06.947Z',
#      'data': 'fcffff0785002a00a7ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 183,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:06.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -52,
#      'sf': 10,
#      'snr': 30,
#      'snr_max': 33.8,
#      'snr_min': 25.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cugjr-R03vmj0MBaw',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:03.979Z',
#      'data': 'fcffff0781001e00a2ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 182,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:03.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -53,
#      'sf': 10,
#      'snr': 24.5,
#      'snr_max': 36.2,
#      'snr_min': 20,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuf00-R03vmj0MBat',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 926375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:00.980Z',
#      'data': 'fcffff077100f3ff8dff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 181,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:00.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -117.8,
#      'sf': 10,
#      'snr': -3.8,
#      'snr_max': -2.2,
#      'snr_min': -4.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuf0h-R03vmj0MBas',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922400000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:37:00.960Z',
#      'data': 'fcffff077100f3ff8dff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 181,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:37:00.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -52,
#      'sf': 10,
#      'snr': 27.5,
#      'snr_max': 35.5,
#      'snr_min': 22,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cufFq-R03vmj0MBaq',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:57.961Z',
#      'data': 'fcffff075700b4ff70ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 180,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:57.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -48,
#      'sf': 10,
#      'snr': 22.5,
#      'snr_max': 30,
#      'snr_min': 15.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cueWX-R03vmj0MBam',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:54.934Z',
#      'data': 'fcffff075400afff70ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 179,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:54.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -41,
#      'sf': 10,
#      'snr': 32.5,
#      'snr_max': 38.8,
#      'snr_min': 25,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cudoJ-R03vmj0MBag',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920400000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:51.976Z',
#      'data': 'fcffff075400adff70ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 178,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -43,
#      'sf': 10,
#      'snr': 32,
#      'snr_max': 40,
#      'snr_min': 27.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuc49-R03vmj0MBaf',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921000000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:48.955Z',
#      'data': 'fcffff075400adff71ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 177,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:48.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -46,
#      'sf': 10,
#      'snr': 27.5,
#      'snr_max': 37,
#      'snr_min': 23.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cucKT-R03vmj0MBad',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:45.970Z',
#      'data': 'fcffff075400adff70ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 176,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:45.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -124.2,
#      'sf': 10,
#      'snr': -9.2,
#      'snr_max': -7.5,
#      'snr_min': -12.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cucJr-R03vmj0MBac',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921400000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:45.930Z',
#      'data': 'fcffff075400adff70ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 176,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:45.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -49,
#      'sf': 10,
#      'snr': 33,
#      'snr_max': 40,
#      'snr_min': 29.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cubbx-R03vmj0MBaZ',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921600000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:42.992Z',
#      'data': 'fcffff075300adff70ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 175,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:42.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -48,
#      'sf': 10,
#      'snr': 26.2,
#      'snr_max': 40,
#      'snr_min': 21.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuar9-R03vmj0MBaX',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:39.933Z',
#      'data': 'fcffff075300acff71ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 174,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:39.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -47,
#      'sf': 10,
#      'snr': 30.5,
#      'snr_max': 36.2,
#      'snr_min': 25.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuYj7-R03vmj0MBaS',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:31.226Z',
#      'data': 'fcffff075100abff71ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 172,
#      'gwid': '00001c497bb44bdc',
#      'gwip': '192.168.88.150',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:30.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -113,
#      'sf': 10,
#      'snr': 17,
#      'snr_max': 21.3,
#      'snr_min': 12.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuYjY-R03vmj0MBaR',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:31.191Z',
#      'data': 'fcffff075100abff71ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 172,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:30.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -102,
#      'sf': 10,
#      'snr': 16.2,
#      'snr_max': 25,
#      'snr_min': 11.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuYi8-R03vmj0MBaQ',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:31.163Z',
#      'data': 'fcffff075100abff71ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 172,
#      'gwid': '00001c497bb44c6a',
#      'gwip': '192.168.88.113',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:30.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -105,
#      'sf': 10,
#      'snr': 13.3,
#      'snr_max': 23.3,
#      'snr_min': 9.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuYgp-R03vmj0MBaP',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:31.016Z',
#      'data': 'fcffff075100abff71ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 172,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:30.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -113,
#      'sf': 10,
#      'snr': 12,
#      'snr_max': 15.8,
#      'snr_min': 8.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuYgd-R03vmj0MBaO',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:31.004Z',
#      'data': 'fcffff075100abff71ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 172,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:36:30.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -79,
#      'sf': 10,
#      'snr': 22.5,
#      'snr_max': 35.5,
#      'snr_min': 12.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cuYgR-R03vmj0MBaN',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:36:30.992Z',
#      'data': 'fcffff075100abff71ff1f',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 172,
#      'gwid': '00001c497bb44bb3',
#      'gwip': '192.168.11.2',
# ...
#      'rssi': -104,
#      'sf': 10,
#      'snr': 13,
#      'snr_max': 19.5,
#      'snr_min': 6.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctnru-R03vmj0MBWo',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 925625000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:33:11.021Z',
#      'data': 'fcffff078aff590079ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 106,
#      'gwid': '00001c497b431e8a',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:33:09.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -133.2,
#      'sf': 10,
#      'snr': -16.2,
#      'snr_max': -14,
#      'snr_min': -19.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctnb9-R03vmj0MBWl',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920600000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:33:10.012Z',
#      'data': 'fcffff078aff590079ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 106,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:33:09.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -48,
#      'sf': 10,
#      'snr': 23.8,
#      'snr_max': 33.8,
#      'snr_min': 18.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctmsy-R03vmj0MBWk',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921000000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:33:06.993Z',
#      'data': 'fcffff078aff580079ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 105,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:33:06.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -48,
#      'sf': 10,
#      'snr': 30,
#      'snr_max': 37.5,
#      'snr_min': 23,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctl9e-R03vmj0MBWi',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:33:03.965Z',
#      'data': 'fcffff078bff58007aff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 104,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:33:03.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -49,
#      'sf': 10,
#      'snr': 27,
#      'snr_max': 37,
#      'snr_min': 17,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctlOx-R03vmj0MBWd',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921800000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:33:00.976Z',
#      'data': 'fcffff078bff58007aff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 103,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:33:00.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -57,
#      'sf': 10,
#      'snr': 30.5,
#      'snr_max': 38,
#      'snr_min': 26.2,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctkfB-R03vmj0MBWb',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922000000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:57.920Z',
#      'data': 'fcffff078bff570078ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 102,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:57.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -54,
#      'sf': 10,
#      'snr': 26.2,
#      'snr_max': 38,
#      'snr_min': 17,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctjwp-R03vmj0MBWa',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923800000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:54.952Z',
#      'data': 'fcffff078bff570078ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 101,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:54.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -66,
#      'sf': 10,
#      'snr': 27,
#      'snr_max': 39.5,
#      'snr_min': 22,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctjHE-R03vmj0MBWX',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:52.291Z',
#      'data': 'fcffff078aff570077ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 100,
#      'gwid': '00001c497bc0de2a',
#      'gwip': '192.168.88.122',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -109,
#      'sf': 10,
#      'snr': 12.5,
#      'snr_max': 18.8,
#      'snr_min': 9.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctjG9-R03vmj0MBWW',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:52.283Z',
#      'data': 'fcffff078aff570077ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 100,
#      'gwid': '00001c497bb44bdc',
#      'gwip': '192.168.88.150',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -107,
#      'sf': 10,
#      'snr': 12,
#      'snr_max': 15.8,
#      'snr_min': 8.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctjFb-R03vmj0MBWV',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:52.186Z',
#      'data': 'fcffff078aff570077ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 100,
#      'gwid': '00001c497b43202f',
#      'gwip': '10.5.180.16',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -107,
#      'sf': 10,
#      'snr': 13.8,
#      'snr_max': 20.5,
#      'snr_min': 7.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctjCt-R03vmj0MBWU',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:52.012Z',
#      'data': 'fcffff078aff570077ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 100,
#      'gwid': '00001c497bb44c6a',
#      'gwip': '192.168.88.113',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -105,
#      'sf': 10,
#      'snr': 2.5,
#      'snr_max': 10,
#      'snr_min': -6.3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctjCa-R03vmj0MBWT',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:51.993Z',
#      'data': 'fcffff078aff570077ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 100,
#      'gwid': '00001c497bb44bb3',
#      'gwip': '192.168.11.2',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -97,
#      'sf': 10,
#      'snr': 19.5,
#      'snr_max': 30.8,
#      'snr_min': 15.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctjCM-R03vmj0MBWS',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:51.980Z',
#      'data': 'fcffff078aff570077ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 100,
#      'gwid': '00001c497b0b7cfd',
#      'gwip': '192.168.0.225',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:31:37.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -105,
#      'sf': 10,
#      'snr': 3.8,
#      'snr_max': 15.5,
#      'snr_min': -3,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctjCK-R03vmj0MBWR',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923400000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:51.977Z',
#      'data': 'fcffff078aff570077ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 100,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -61,
#      'sf': 10,
#      'snr': 25,
#      'snr_max': 39.5,
#      'snr_min': 20,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctjCG-R03vmj0MBWQ',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 923375000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:51.973Z',
#      'data': 'fcffff078aff570077ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 100,
#      'gwid': '00001c497b431e8f',
#      'gwip': '192.168.0.3',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:51.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -59,
#      'sf': 10,
#      'snr': 18,
#      'snr_max': 24.5,
#      'snr_min': 12.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctiTH-R03vmj0MBWO',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:48.966Z',
#      'data': 'fcffff078bff580078ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 99,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:48.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -48,
#      'sf': 10,
#      'snr': 33,
#      'snr_max': 42.5,
#      'snr_min': 23.8,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctg0r-R03vmj0MBWL',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920600000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:42.922Z',
#      'data': 'fcffff078cff590078ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 98,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:42.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -49,
#      'sf': 10,
#      'snr': 30.5,
#      'snr_max': 37,
#      'snr_min': 20.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctgGh-R03vmj0MBWH',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 920800000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:39.968Z',
#      'data': 'fcffff078cff590078ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 97,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:39.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -48,
#      'sf': 10,
#      'snr': 24.5,
#      'snr_max': 34.5,
#      'snr_min': 19.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctfXx-R03vmj0MBWE',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921200000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:36.976Z',
#      'data': 'fcffff078cff590079ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 96,
#      'gwid': '00001c497b431e38',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:36.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -48,
#      'sf': 10,
#      'snr': 25,
#      'snr_max': 39.5,
#      'snr_min': 17.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2cteox-R03vmj0MBWC',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 921800000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:33.968Z',
#      'data': 'fcffff078cff580079ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 95,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:33.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -56,
#      'sf': 10,
#      'snr': 29.5,
#      'snr_max': 35.5,
#      'snr_min': 24.5,
#      'systype': 13},
#     '_type': 'parking_record_type'},
#    {'_id': 'AV2ctd5n-R03vmj0MBV_',
#     '_index': 'parking_record_index_v2',
#     '_score': None,
#     '_source': {'channel': 922000000,
#      'commsysType': 'lora',
#      'create_at': '2017-08-01T07:32:30.951Z',
#      'data': 'fcffff078cff580079ff20',
#      'doc_type': 'parking_record',
#      'extra': {'company': 'yilan',
#       'road': '宜蘭市中山路二段',
#       'slot_num': '111',
#       'type': 'node'},
#      'fport': 1,
#      'frameCnt': 94,
#      'gwid': '00001c497b431e2e',
#      'gwip': '10.5.151.1',
#      'macAddr': '101a0d01019a',
#      'recv': '2017-08-01T07:32:30.000Z',
#      'repeater': '00000000ffffffff',
#      'rssi': -56,
#      'sf': 10,
#      'snr': 30.5,
#      'snr_max': 36.2,
#      'snr_min': 24.5,
#      'systype': 13},
#     '_type': 'parking_record_type'}],
#   'max_score': None,
#   'total': 1293}}

# %%
import matplotlib.pyplot as plt


df.to_csv(csvFileName, encoding='utf_8_sig')

plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()
